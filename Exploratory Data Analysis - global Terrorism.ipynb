# %% [markdown]
# ## Exploratory Data Analysis on the dataset -"Global Terrorism"
#
# ## - B RAVI TEJA

# %% [markdown]
# ### Objective: As a Security/Defence analyst, try to find the hot zones of terrorism
# ### and what all the security issues and insights can be derived by EDA.

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading the data

# %%
df = pd.read_csv('D:/GRIP/globalterrorism.csv', encoding = "ISO-8859-1", engine='python')

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
#Displaying the column names 

df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
#Displaying the sum of Null values in each column

df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
df2 = df.copy()                           #copying the dataset into new dataframe

# %%
df2.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
#    INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0        0         0        0       0      NaN
# 1        0         1        1       1      NaN
# 2       -9        -9        1       1      NaN
# 3       -9        -9        1       1      NaN
# 4       -9        -9        1       1      NaN
#
# [5 rows x 135 columns]

# %%
df2.dropna(axis=1, how='all')                  #dropping the columns which have null values
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# 0            58  Dominican Republic       2  ...      NaN
# 1           130              Mexico       1  ...      NaN
# 2           160         Philippines       5  ...      NaN
# 3            78              Greece       8  ...      NaN
# 4           101               Japan       4  ...      NaN
# ...         ...                 ...     ...  ...      ...
# 181686      182             Somalia      11  ...      NaN
# 181687      200               Syria      10  ...      NaN
# 181688      160         Philippines       5  ...      NaN
# 181689       92               India       6  ...      NaN
# 181690      160         Philippines       5  ...      NaN
#
#                                                    scite1  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# 181688  "Maguindanao clashes trap tribe members," Phil...
# 181689  "Trader escapes grenade attack in Imphal," Bus...
# 181690  "Security tightened in Cotabato following IED ...
#
#                                                    scite2  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 2 ...
# 181687  "Two Russian soldiers killed at Hmeymim base i...
# 181688                                                NaN
# 181689                                                NaN
# 181690  "Security tightened in Cotabato City," Manila ...
#
#                                                    scite3  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 181686  "Highlights: Somalia Daily Media Highlights 1 ...
# 181687  "Two Russian servicemen killed in Syria mortar...
# 181688                                                NaN
# 181689                                                NaN
# 181690                                                NaN
#
#                         dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  related
# 0                           PGIS        0         0        0       0      NaN
# 1                           PGIS        0         1        1       1      NaN
# 2                           PGIS       -9        -9        1       1      NaN
# 3                           PGIS       -9        -9        1       1      NaN
# 4                           PGIS       -9        -9        1       1      NaN
# ...                          ...      ...       ...      ...     ...      ...
# 181686  START Primary Collection        0         0        0       0      NaN
# 181687  START Primary Collection       -9        -9        1       1      NaN
# 181688  START Primary Collection        0         0        0       0      NaN
# 181689  START Primary Collection       -9        -9        0      -9      NaN
# 181690  START Primary Collection       -9        -9        0      -9      NaN
#
# [181691 rows x 135 columns]

# %% [markdown]
# ### Renaming the columns, to read and understand easily

# %%
df2.rename(columns={'iyear':'Year','imonth':'Month','iday':'Day','country_txt':'Country','provstate':'state',
                       'region_txt':'Region','attacktype1_txt':'AttackType','target1':'Target','nkill':'Killed',
                       'nwound':'Wounded','summary':'Summary','gname':'Group','targtype1_txt':'Target_type',
                       'weaptype1_txt':'Weapon_type','motive':'Motive'},inplace=True)

# %% [markdown]
# #### Considering only usefull columns

# %%
df2=df2[['Year','Month','Day','Country','state','Region','city','latitude','longitude','AttackType','Killed',
               'Wounded','Target','Summary','Group','Target_type','Weapon_type','Motive']]
df2['Wounded'] = df2['Wounded'].fillna(0).astype(int)
df2['Killed'] = df2['Killed'].fillna(0).astype(int)                            #filling the null value with zeros

# %%
df2['casualities']=df2['Killed']+df2['Wounded']            #adding a new column 'casuality'

# %%
df2.head()
# Out:
#    Year  Month  Day             Country    state                       Region  \
# 0  1970      7    2  Dominican Republic      NaN  Central America & Caribbean
# 1  1970      0    0              Mexico  Federal                North America
# 2  1970      1    0         Philippines   Tarlac               Southeast Asia
# 3  1970      1    0              Greece   Attica               Western Europe
# 4  1970      1    0               Japan  Fukouka                    East Asia
#
#             city   latitude   longitude                      AttackType  \
# 0  Santo Domingo  18.456792  -69.951164                   Assassination
# 1    Mexico city  19.371887  -99.086624     Hostage Taking (Kidnapping)
# 2        Unknown  15.478598  120.599741                   Assassination
# 3         Athens  37.997490   23.762728               Bombing/Explosion
# 4        Fukouka  33.580412  130.396361  Facility/Infrastructure Attack
#
#    Killed  Wounded                   Target Summary  \
# 0       1        0             Julio Guzman     NaN
# 1       0        0  Nadine Chaval, daughter     NaN
# 2       1        0                 Employee     NaN
# 3       0        0             U.S. Embassy     NaN
# 4       0        0           U.S. Consulate     NaN
#
#                                 Group                  Target_type  \
# 0                              MANO-D  Private Citizens & Property
# 1  23rd of September Communist League      Government (Diplomatic)
# 2                             Unknown          Journalists & Media
# 3                             Unknown      Government (Diplomatic)
# 4                             Unknown      Government (Diplomatic)
#
#   Weapon_type Motive  casualities
# 0     Unknown    NaN            1
# 1     Unknown    NaN            0
# 2     Unknown    NaN            1
# 3  Explosives    NaN            0
# 4  Incendiary    NaN            0

# %%
df2.isnull().sum()
# Out:
# Year                0
# Month               0
# Day                 0
# Country             0
# state             421
# Region              0
# city              434
# latitude         4556
# longitude        4557
# AttackType          0
# Killed              0
# Wounded             0
# Target            636
# Summary         66129
# Group               0
# Target_type         0
# Weapon_type         0
# Motive         131130
# casualities         0
# dtype: int64

# %% [markdown]
# ### Basic analysis of the data

# %%
print("The country with highest terror attack:",df2['Country'].value_counts().index[0])
print("Regions with highest terrorist attacks: ",df2['Region'].value_counts().index[0])
print("Highest people killed in an attack",df2['Killed'].max(),"that too place in",df2.loc[df2['Killed'].idxmax()].Country)
print("City with the highest number of attacks:",df2['city'].value_counts().index[1])
print("Year with the most attacks:",df2['Year'].value_counts().idxmax())
print("Month with the most attacks:",df2['Month'].value_counts().idxmax())
print("Group with the most attacks:",df2['Group'].value_counts().index[1])
print("Most Attack Types:",df2['AttackType'].value_counts().idxmax())
# Out:
# The country with highest terror attack: Iraq
# Regions with highest terrorist attacks:  Middle East & North Africa
# Highest people killed in an attack 1570 that too place in Iraq
# City with the highest number of attacks: Baghdad
# Year with the most attacks: 2014
# Month with the most attacks: 5
# Group with the most attacks: Taliban
# Most Attack Types: Bombing/Explosion

# %% [markdown]
# ## Comparing the number of Terrorist Attacks and the number of Dead/Injured people from 1970 to 2017

# %%
#Filter Data to choose Number Of Dead/Injured People In Terrorist Attacks From 1970 to 2017
people_damage = df2[["Year","casualities"]].groupby('Year').sum()
list_year =  df2["Year"].unique().tolist()

#draw bar chart
fig, ax1 = plt.subplots(figsize = (20,6))
ax1.bar(people_damage.index, [i[0] for i in people_damage.values], color= '#0063B1' )

ax1.set_xticklabels(np.arange(1970, 2018, step=1), rotation=90)
ax1.set_ylabel('Number Of Dead/Injured People', size = 12)
ax1.set_xlabel('Year', size = 12)
ax1.set_title('Number of Terrorist Attacks vs Number of Dead/Injured people From 1970 to 2017', fontsize= 15, pad= 10, weight ='bold', 
                    color = sns.cubehelix_palette(8, start=.5, rot=-.75)[-3])
ax2 = ax1.twinx()

#Filter & get a number of attacked in the world from 1970 to 2017 
number_attack = []
for year in list_year:
    number_attack.append(len(df2[df2['Year'] == year][["Year"]]))
number_attack.insert(23, 0)

#draw plot chart
ax2.set_ylabel('Number Of Terrorist Attacks', size = 12,rotation=-90)
ax2.plot(range(1970, 2018), number_attack, 'r--o', mfc='k', label='Number Of Terrorist Attacks')

plt.xticks(np.arange(1970, 2018, step=1))
plt.legend(loc='upper left')
plt.show()

# %%
import warnings; warnings.simplefilter('ignore')
terror_region=pd.crosstab(df2.Year,df2.Region)
terror_region.plot(color=sns.color_palette('Paired',12))
fig=plt.gcf()
fig.set_size_inches(18,6)
plt.show()

# %% [markdown]
# ### The below plot shows the number of terrorist activities took place in each year

# %%
plt.subplots(figsize=(15,6))
sns.countplot('Year',data=df2,palette="coolwarm",edgecolor=sns.color_palette('dark',7))
plt.xticks(rotation=90)
plt.title("Number of Terrorist Activities in each Year", fontsize=20)
plt.show()

# %% [markdown]
# ### From the above plot we can see that in the year 2014, themaximum terrorist activities took place

# %%
f,ax = plt.subplots(figsize=(8,8))
sns.heatmap(df2.corr(), annot=False, linewidths=.4, fmt =".1f=",cmap=sns.diverging_palette(20,220,n=200), ax=ax)

# %% [markdown]
# ### The below plot shows the most used attacking methods by the terrorists

# %%
plt.subplots(figsize=(15,6))
sns.countplot('AttackType',data=df2,palette='rocket',order=df2['AttackType'].value_counts().index)
plt.xticks(rotation=90)
plt.title("The Attacking methods used by terrorists", fontsize=20)
plt.show()

# %% [markdown]
# ## From the above plot we can see that Bombing/Explosion is the most used attacking method by terrorists

# %% [markdown]
# ### The below plot shows the favorite targets of terrorists for attacking

# %%
plt.subplots(figsize=(15,6))
sns.countplot('Target_type',data=df2,palette='mako',order=df2['Target_type'].value_counts().index)
plt.xticks(rotation=90)
plt.title("Favorite Targets", fontsize=18)
plt.show()

# %% [markdown]
# ## From the above plot we can see that the private citizens and property are targeted the most

# %% [markdown]
# ### The below plot shows the most affected region by terrorist activity

# %%
plt.subplots(figsize=(15,6))
sns.countplot('Region',data=df2,palette='Paired',edgecolor=sns.color_palette('dark',7),order=df2['Region'].value_counts().index)
plt.xticks(rotation=90)
plt.title('Number Of Terrorist Activities By Region', fontsize=20)
plt.show()

# %% [markdown]
# ### From the above plot we can see that the Middle East and North Africa are the most affected regions by terrorism

# %%
pd.crosstab(df2.Region,df2.AttackType).plot.barh(stacked=True,width=1,color=sns.color_palette('Paired',9))
fig=plt.gcf()
fig.set_size_inches(12,8)
plt.show()

# %% [markdown]
# ### The below plot shows the most affected countries

# %%
plt.subplots(figsize=(18,6))
ax=sns.barplot(df2['Country'].value_counts()[:15].index,df2['Country'].value_counts()[:15].values,palette='magma')

for rect in ax.patches:
   
    height = rect.get_height()
    width = rect.get_width()
    x = rect.get_x()
    y = rect.get_y()
    
    label_text = f'{height}'  
    
    label_x = x + width / 2
    label_y = y + height / 2

    if height > 0:
        ax.text(label_x, label_y, label_text, ha='center', va='center', color='white', fontsize=8)

plt.title('Top Affected Countries', fontsize=20)
plt.show()

# %% [markdown]
# ## From the above plot we can see that the Iraq is the most affected country by terrorism

# %% [markdown]
# ### The below plot shows the number of attacks and how many people were wounded and killed

# %%
f,ax = plt.subplots(figsize=(18,10))
ax.set_facecolor('grey')
df2.Killed.plot(kind="line",color = "black", label="Number of kills",linewidth=5, alpha=0.5, grid=True, linestyle=":")
df2.Wounded.plot(color="blue", label="Number of wounds",linewidth=5, alpha=0.5, grid=True,linestyle=":")
plt.legend(loc="upper right")
plt.xlabel("Number of attacks", size=15)
plt.ylabel("People", size=15)
# Out:
# Text(0, 0.5, 'People')

# %% [markdown]
# ## The below plot shows the number of attacks that took place and the number of people were killed

# %%
coun_terror=df2['Country'].value_counts()[:15].to_frame()
coun_terror.columns=['Attacks']
coun_kill=df2.groupby('Country')['Killed'].sum().to_frame()
coun_terror.merge(coun_kill,left_index=True,right_index=True,how='left').plot.bar(width=0.9)
plt.ylabel("Number of Attacks and Kills", fontsize=18)
plt.xlabel("Countries", fontsize=18)
fig=plt.gcf()
fig.set_size_inches(18,6)
plt.show()

# %% [markdown]
# ## In the above plot we can see that the maximum attacks and kills took place in iraq

# %% [markdown]
# ### The below plot shows the number of kills that took place over the years and what type of weapons were used the most

# %%
sns.lmplot(x='Year', y='Killed',data=df2,fit_reg=False,hue='Weapon_type',legend=True ,                       
           palette="Set1",aspect=15/10)
plt.xlabel("years")
plt.ylabel("kills") 
plt.title("Year-wise number of kills by used weapon types", fontsize=20)
# Out:
# Text(0.5, 1.0, 'Year-wise number of kills by used weapon types')

# %% [markdown]
# ## The below plot shows the terrorist groups with highest terror attacks

# %%
ax=sns.barplot(df2['Group'].value_counts()[1:15].values,df2['Group'].value_counts()[1:15].index,palette=('inferno'))

for rect in ax.patches:
   
    height = rect.get_height()
    width = rect.get_width()
    x = rect.get_x()
    y = rect.get_y()
    
    label_text = f'{width}'  
    
    label_x = x + width / 2
    label_y = y + height / 2

    if width > 0:
        ax.text(label_x, label_y, label_text, ha='center', va='center', color='white', fontsize=10)

plt.xticks(rotation=90)
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.title('Terrorist Organisations with Highest Terror Attacks', fontsize=20)
plt.show()

# %% [markdown]
# ## From the above plot we can see that the highest terror attacks are caused by Taliban terrorist organisation

# %%
terror_df=df2[(df2['Group']!='Unknown')& (df2['casualities']>50)]      #creating a new dataframe
terror_df.head()
# Out:
#       Year  Month  Day         Country             state  \
# 1200  1972      3    4  United Kingdom  Northern Ireland
# 1314  1972      5   30          Israel           Central
# 1789  1973      3    8  United Kingdom           England
# 1972  1973      8    5          Greece            Attica
# 2138  1973     12   17           Italy             Lazio
#
#                           Region     city   latitude  longitude  \
# 1200              Western Europe  Belfast  54.607712  -5.956210
# 1314  Middle East & North Africa      Lod  32.004361  34.888229
# 1789              Western Europe   London  51.504387  -0.140041
# 1972              Western Europe   Athens  37.997490  23.762728
# 2138              Western Europe     Rome  41.890961  12.490069
#
#                                AttackType  Killed  Wounded  \
# 1200                    Bombing/Explosion       2      130
# 1314                    Bombing/Explosion      26       72
# 1789                    Bombing/Explosion       1      238
# 1972                    Bombing/Explosion       5       55
# 2138  Hostage Taking (Barricade Incident)      30       50
#
#                                               Target Summary  \
# 1200  Janet Bereen, 21 and Anne Owens, 22, Catholics     NaN
# 1314                               Aircraft Terminal     NaN
# 1789                                  Court Building     NaN
# 1972                                      TWA Lounge     NaN
# 2138            Pan Am Lounge and Loading Pan Am 707     NaN
#
#                             Group           Target_type Weapon_type Motive  \
# 1200  Irish Republican Army (IRA)              Business  Explosives    NaN
# 1314      Japanese Red Army (JRA)   Airports & Aircraft    Firearms    NaN
# 1789  Irish Republican Army (IRA)  Government (General)  Explosives    NaN
# 1972              Black September   Airports & Aircraft    Firearms    NaN
# 2138              Black September   Airports & Aircraft    Firearms    NaN
#
#       casualities
# 1200          132
# 1314           98
# 1789          239
# 1972           60
# 2138           80

# %%
terror_df = terror_df.sort_values(['Region','Country'])
terror_df.head()
# Out:
#        Year  Month  Day      Country          state  \
# 4198   1976     10    6     Barbados  Christ Church
# 11087  1980      6    2  El Salvador        Morazan
# 12110  1980     10   18  El Salvador       Usulutan
# 12673  1981      1   17  El Salvador       La Union
# 15592  1982      3    3  El Salvador    San Vicente
#
#                             Region                                 city  \
# 4198   Central America & Caribbean  Grantly Adams International Airport
# 11087  Central America & Caribbean                              Osicala
# 12110  Central America & Caribbean                          San Agustin
# 12673  Central America & Caribbean                      Albornoz Arriba
# 15592  Central America & Caribbean                      Amatitan Arriba
#
#         latitude  longitude         AttackType  Killed  Wounded  \
# 4198   13.077333 -59.493008  Bombing/Explosion      73        0
# 11087  13.805691 -88.145787      Armed Assault      40      100
# 12110  13.432040 -88.592239            Unknown      58        0
# 12673  13.582486 -87.945460      Armed Assault      87        0
# 15592  13.755754 -88.732730      Armed Assault      60        0
#
#                                           Target Summary  \
# 4198                        Cubana Airlines DC-8     NaN
# 11087                        national guard unit     NaN
# 12110  18 guardsmen, + 40 of their collaborators     NaN
# 12673                             Military Units     NaN
# 15592                              Military unit     NaN
#
#                                                    Group          Target_type  \
# 4198   Coordination of the United Revolutionary Organ...  Airports & Aircraft
# 11087   Farabundo Marti National Liberation Front (FMLN)             Military
# 12110   Farabundo Marti National Liberation Front (FMLN)               Police
# 12673   Farabundo Marti National Liberation Front (FMLN)             Military
# 15592   Farabundo Marti National Liberation Front (FMLN)             Military
#
#       Weapon_type Motive  casualities
# 4198   Explosives    NaN           73
# 11087    Firearms    NaN          140
# 12110     Unknown    NaN           58
# 12673    Firearms    NaN           87
# 15592    Firearms    NaN           60

# %%
terror_df.isnull().sum()
# Out:
# Year              0
# Month             0
# Day               0
# Country           0
# state             3
# Region            0
# city              1
# latitude         62
# longitude        62
# AttackType        0
# Killed            0
# Wounded           0
# Target            9
# Summary         517
# Group             0
# Target_type       0
# Weapon_type       0
# Motive         1059
# casualities       0
# dtype: int64

# %% [markdown]
# ### Dropping the columns that are least necessary for the analysis

# %%
terror_df = terror_df.drop(['latitude','longitude','Motive','Summary','Target'],axis=1)
terror_df.head()
# Out:
#        Year  Month  Day      Country          state  \
# 4198   1976     10    6     Barbados  Christ Church
# 11087  1980      6    2  El Salvador        Morazan
# 12110  1980     10   18  El Salvador       Usulutan
# 12673  1981      1   17  El Salvador       La Union
# 15592  1982      3    3  El Salvador    San Vicente
#
#                             Region                                 city  \
# 4198   Central America & Caribbean  Grantly Adams International Airport
# 11087  Central America & Caribbean                              Osicala
# 12110  Central America & Caribbean                          San Agustin
# 12673  Central America & Caribbean                      Albornoz Arriba
# 15592  Central America & Caribbean                      Amatitan Arriba
#
#               AttackType  Killed  Wounded  \
# 4198   Bombing/Explosion      73        0
# 11087      Armed Assault      40      100
# 12110            Unknown      58        0
# 12673      Armed Assault      87        0
# 15592      Armed Assault      60        0
#
#                                                    Group          Target_type  \
# 4198   Coordination of the United Revolutionary Organ...  Airports & Aircraft
# 11087   Farabundo Marti National Liberation Front (FMLN)             Military
# 12110   Farabundo Marti National Liberation Front (FMLN)               Police
# 12673   Farabundo Marti National Liberation Front (FMLN)             Military
# 15592   Farabundo Marti National Liberation Front (FMLN)             Military
#
#       Weapon_type  casualities
# 4198   Explosives           73
# 11087    Firearms          140
# 12110     Unknown           58
# 12673    Firearms           87
# 15592    Firearms           60

# %%
terror_df = terror_df.dropna(subset=['city'])   #droppping the null values from city

# %%
terror_df.isnull().sum()
# Out:
# Year           0
# Month          0
# Day            0
# Country        0
# state          3
# Region         0
# city           0
# AttackType     0
# Killed         0
# Wounded        0
# Group          0
# Target_type    0
# Weapon_type    0
# casualities    0
# dtype: int64

# %% [markdown]
# ## Plotting the graph of four most affected countries

# %%
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
hover_text = []
for index, row in terror_df.iterrows():
    hover_text.append(('City: {city}<br>'+'Group: {group}<br>'+'casualities: {casualities}<br>'+
                       'Year: {Year}').format(city=row['city'],
                                            group=row['Group'],
                                            casualities=row['casualities'],
                                            Year=row['Year']))
terror_df['text'] = hover_text

# %%
trace0 = go.Scatter(
    x=terror_df['Year'][terror_df['Country'] == 'Iraq'],
    y=terror_df['casualities'][terror_df['Country'] == 'Iraq'],
    mode='markers',
    name='Iraq',
    text=terror_df['text'][terror_df['Country'] == 'Iraq'],
    marker=dict(
        symbol='circle',
        sizemode='area',
        size=terror_df['casualities'][terror_df['Country'] == 'Iraq'],
        line=dict(width=2),)
)

trace1 = go.Scatter(
    x=terror_df['Year'][terror_df['Country'] == 'Pakistan'],
    y=terror_df['casualities'][terror_df['Country'] == 'Pakistan'],
    mode='markers',
    name='Pakistan',
    text=terror_df['text'][terror_df['Country'] == 'Pakistan'],
    marker=dict(
        symbol='circle',
        sizemode='area',
        size=terror_df['casualities'][terror_df['Country'] == 'Pakistan'],
        line=dict(width=2),)
)

trace2 = go.Scatter(
    x=terror_df['Year'][terror_df['Country'] == 'Afghanistan'],
    y=terror_df['casualities'][terror_df['Country'] == 'Afghanistan'],
    mode='markers',
    name='Afghanistan',
    text=terror_df['text'][terror_df['Country'] == 'Afghanistan'],
    marker=dict(
        symbol='circle',
        sizemode='area',
        size=terror_df['casualities'][terror_df['Country'] == 'Afghanistan'],
        line=dict(width=2),)
)

trace3 = go.Scatter(
    x=terror_df['Year'][terror_df['Country'] == 'India'],
    y=terror_df['casualities'][terror_df['Country'] == 'India'],
    mode='markers',
    name='India',
    text=terror_df['text'][terror_df['Country'] == 'India'],
    marker=dict(
        symbol='circle',
        sizemode='area',
        size=terror_df['casualities'][terror_df['Country'] == 'India'],
        line=dict(width=2),)
)

# %%
data = [trace0, trace1, trace2, trace3]
layout = go.Layout(
         title = 'The Four most affected countries by terrorism',
         xaxis = dict(
             title = 'Year',
             range = [1976,2016],
             tickmode = 'auto',
             nticks = 30,
             showline = True,
             showgrid = False,color='black'
             ),
         yaxis = dict(
             title = 'Casualities',
             type = 'log',
             range = [1.8,3.6],
             tickmode = 'auto',
             nticks = 40,
             showline = True,
             showgrid = False,color='black'),
    paper_bgcolor='rgb(130, 225, 238)',
    plot_bgcolor='rgb(130, 225, 238)')

# %%
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='Terrorism Bubble')
# Out:
# <div>                            <div id="d817f7d8-51f8-4023-96f7-14591d4cfdde" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d817f7d8-51f8-4023-96f7-14591d4cfdde")) {                    Plotly.newPlot(                        "d817f7d8-51f8-4023-96f7-14591d4cfdde",                        [{"marker": {"line": {"width": 2}, "size": [158, 76, 140, 60, 91, 217, 57, 68, 124, 300, 57, 62, 60, 68, 221, 112, 343, 225, 73, 68, 174, 280, 52, 126, 56, 161, 61, 51, 89, 210, 57, 88, 100, 142, 155, 85, 72, 101, 702, 68, 60, 108, 90, 65, 173, 191, 71, 85, 292, 102, 251, 275, 118, 96, 84, 1000, 1000, 220, 186, 122, 102, 88, 85, 73, 66, 103, 63, 176, 140, 121, 87, 80, 75, 123, 124, 73, 294, 130, 96, 131, 95, 654, 436, 437, 126, 126, 126, 127, 127, 80, 148, 181, 91, 133, 112, 68, 67, 200, 55, 81, 84, 181, 58, 91, 133, 211, 163, 92, 57, 93, 62, 115, 61, 91, 58, 54, 56, 57, 65, 65, 74, 69, 108, 118, 106, 55, 64, 83, 78, 64, 51, 85, 91, 118, 86, 56, 53, 61, 74, 57, 204, 81, 53, 68, 66, 109, 107, 670, 69, 53, 63, 1570, 69, 80, 61, 76, 86, 114, 67, 953, 91, 400, 70, 150, 187, 58, 77, 150, 75, 71, 150, 107, 61, 85, 71, 77, 71, 97, 53, 55, 66, 300, 57, 54, 64, 53, 52, 81, 251, 52, 66, 132, 220, 56, 70, 99, 65, 83, 142, 71, 138, 300, 57, 60, 94, 93, 89, 157, 1503, 91, 51, 250, 51, 68, 60, 52, 61, 152, 65, 52, 649, 53, 583, 72, 130, 56, 97, 100, 70, 69, 182, 284, 190, 70, 112, 61, 118, 100, 130, 56, 93, 60, 97, 75, 93, 95, 51, 72, 230, 151, 61, 78, 57, 64, 59, 53, 163, 55, 100, 200, 111, 93, 90, 122], "sizemode": "area", "symbol": "circle"}, "mode": "markers", "name": "Iraq", "text": ["City: Baghdad<br>Group: Iraqi Mujahideen<br>casualities: 158<br>Year: 1982", "City: Baghdad<br>Group: Martyr Abu Ja'far Group<br>casualities: 76<br>Year: 1982", "City: Nero-Soto<br>Group: Kurdish Democratic Party-Iraq (KDP)<br>casualities: 140<br>Year: 1988", "City: Hakurk<br>Group: Anti Kurdish Workers Party Iraq nationals<br>casualities: 60<br>Year: 1992", "City: Sulaymaniyah<br>Group: Patriotic Union of Kurdistan (PUK)<br>casualities: 91<br>Year: 1994", "City: Zakho<br>Group: Patriotic Union of Kurdistan (PUK)<br>casualities: 217<br>Year: 1995", "City: Sidakan<br>Group: Kurdistan Workers' Party (PKK)<br>casualities: 57<br>Year: 1997", "City: Baghdad<br>Group: Ansar al-Islam<br>casualities: 68<br>Year: 2003", "City: Baghdad<br>Group: Armed Vanguards of a Second Mohammed Army<br>casualities: 124<br>Year: 2003", "City: Najaf<br>Group: Tawhid and Jihad<br>casualities: 300<br>Year: 2003", "City: Arbil<br>Group: Tawhid and Jihad<br>casualities: 57<br>Year: 2003", "City: Karbala<br>Group: Baathist extremists<br>casualities: 62<br>Year: 2003", "City: Karbala<br>Group: Baathist extremists<br>casualities: 60<br>Year: 2003", "City: Karbala<br>Group: Baathist extremists<br>casualities: 68<br>Year: 2003", "City: Iskandariyah<br>Group: Tawhid and Jihad<br>casualities: 221<br>Year: 2004", "City: Hillah<br>Group: Tawhid and Jihad<br>casualities: 112<br>Year: 2004", "City: Karbala<br>Group: Tawhid and Jihad<br>casualities: 343<br>Year: 2004", "City: Baghdad<br>Group: Tawhid and Jihad<br>casualities: 225<br>Year: 2004", "City: Baghdad<br>Group: Tawhid and Jihad<br>casualities: 73<br>Year: 2004", "City: Baghdad<br>Group: Mahdi Army<br>casualities: 68<br>Year: 2004", "City: Basra<br>Group: Tawhid and Jihad<br>casualities: 174<br>Year: 2004", "City: Mosul<br>Group: Tawhid and Jihad<br>casualities: 280<br>Year: 2004", "City: Mahmudiyah<br>Group: Tawhid and Jihad<br>casualities: 52<br>Year: 2004", "City: Baqubah<br>Group: Tawhid and Jihad<br>casualities: 126<br>Year: 2004", "City: Kirkuk<br>Group: Tawhid and Jihad<br>casualities: 56<br>Year: 2004", "City: Baghdad<br>Group: Tawhid and Jihad<br>casualities: 161<br>Year: 2004", "City: Baghdad<br>Group: Tawhi ...

# %% [markdown]
# ### value count of attacks carried out by the terrorist organisations

# %%
df2.Group.value_counts()[1:15]
# Out:
# Taliban                                             7478
# Islamic State of Iraq and the Levant (ISIL)         5613
# Shining Path (SL)                                   4555
# Farabundo Marti National Liberation Front (FMLN)    3351
# Al-Shabaab                                          3288
# New People's Army (NPA)                             2772
# Irish Republican Army (IRA)                         2671
# Revolutionary Armed Forces of Colombia (FARC)       2487
# Boko Haram                                          2418
# Kurdistan Workers' Party (PKK)                      2310
# Basque Fatherland and Freedom (ETA)                 2024
# Communist Party of India - Maoist (CPI-Maoist)      1878
# Maoists                                             1630
# Liberation Tigers of Tamil Eelam (LTTE)             1606
# Name: Group, dtype: int64

# %% [markdown]
# ## The below map shows the parts of the countries that are attacked by the top 8 terrorist organisations

# %%
import folium
from folium.plugins import MarkerCluster

# %%
terror_group = df2.dropna(subset=['latitude','longitude'])

# %%
terror_group = terror_group.drop_duplicates(subset=['Country','Group'])

# %%
terrorist_groups = df2.Group.value_counts()[1:8].index.tolist()

# %%
terror_group = terror_group.loc[terror_group.Group.isin(terrorist_groups)]

# %%
terror_group.Group.unique()
# Out:
# array(["New People's Army (NPA)", 'Irish Republican Army (IRA)',
#        'Shining Path (SL)',
#        'Farabundo Marti National Liberation Front (FMLN)', 'Taliban',
#        'Al-Shabaab', 'Islamic State of Iraq and the Levant (ISIL)'],
#       dtype=object)

# %%
m1 = folium.Map(location=[20, 0], tiles="Stamenterrain", zoom_start=2)
marker_cluster = MarkerCluster(
    name='clustered icons',overlay=True,control=False,icon_create_function=None)
for i in range(0,len(terror_group)):
    marker=folium.Marker([terror_group.iloc[i]['latitude'],terror_group.iloc[i]['longitude']]) 
    popup='Group:{}<br>Country:{}'.format(terror_group.iloc[i]['Group'],
                                          terror_group.iloc[i]['Country'])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)
marker_cluster.add_to(m1)
folium.TileLayer('openstreetmap').add_to(m1)
folium.TileLayer('Mapbox Bright').add_to(m1)
folium.TileLayer('cartodbdark_matter').add_to(m1)
folium.TileLayer('stamentoner').add_to(m1)
folium.LayerControl().add_to(m1)

# %%
m1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
from folium.plugins import HeatMap

# %%
attack=df2.loc[df2.Year==2014][['latitude','longitude']]
attack.latitude.fillna(0, inplace = True)
attack.longitude.fillna(0, inplace = True) 

World =folium.Map(location=[0,0],zoom_start=2)
HeatMap(data=attack, radius=16).add_to(World)
print('Terrorism around the world in 2014')
World
# Out:
# Terrorism around the world in 2014
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## The above map shows the terrorism that took place in the year 2014,as 2014 is the year in which maximum terror attack took place

# %% [markdown]
# ## Thank you
